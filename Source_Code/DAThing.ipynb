# %%
import tkinter as tk
from tkinter.ttk import *
import cv2
from PIL import Image, ImageTk
from tkinter import filedialog
import pandas as pd
from ultralytics import YOLO
import cvzone
import threading
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# Global variables for OpenCV-related objects and flags
cap = None
is_camera_on = False
model = YOLO('yolov8m.pt')
video_paused = False

# Function to read coco.txt
def read_classes_from_file(file_path):
    with open(file_path, 'r') as file:
        classes = [line.strip() for line in file]
    return classes

# Function to start the webcam feed
def start_webcam():
    global cap, is_camera_on, video_paused
    if not is_camera_on:
        cap = cv2.VideoCapture(0)  # Use the default webcam (you can change the index if needed)
        is_camera_on = True
        video_paused = False
        update_canvas()  # Start updating the canvas

# Function to stop the webcam feed
def stop_webcam():
    global cap, is_camera_on, video_paused
    if cap is not None:
        cap.release()
        is_camera_on = False
        video_paused = False

# Function to pause or resume the video
def pause_resume_video():
    global video_paused
    video_paused = not video_paused

# Function to start video playback from a file
def select_file():
    global cap, is_camera_on, video_paused
    if is_camera_on:
        stop_webcam()  # Stop the webcam feed if running
    file_path = filedialog.askopenfilename(filetypes=[("Video files", "*.mp4 *.avi *.mov")])
    if file_path:
        cap = cv2.VideoCapture(file_path)
        is_camera_on = True
        video_paused = False
        update_canvas()  # Start updating the canvas with the video

# Function to update the Canvas with the webcam frame or video frame
def update_canvas():
    global is_camera_on, frame_count, video_paused
    if is_camera_on:
        if not video_paused:
            ret, frame = cap.read()
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.resize(frame, (1020, 500))
            selected_class = class_selection.get()

            results = model.predict(frame)
            a = results[0].boxes.data
            px_np = pd.DataFrame(a.cpu().numpy()).astype("float")
            px = torch.from_numpy(px_np.values).to('cuda')
            px_np = px.cpu().numpy()
            for row in px_np:
                x1 = int(row[0])
                y1 = int(row[1])
                x2 = int(row[2])
                y2 = int(row[3])
                d = int(row[5])
                c = class_list[d]
                if selected_class == "All" or c == selected_class:
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                    cvzone.putTextRect(frame, f'{c}', (x1, y1), 1, 1)

            photo = ImageTk.PhotoImage(image=Image.fromarray(frame))
            canvas.img = photo
            canvas.create_image(0, 0, anchor=tk.NW, image=photo)

        canvas.after(1, update_canvas)

# Function to quit the application
def quit_app():
    stop_webcam()
    root.quit()
    root.destroy()

# Create the main Tkinter window
root = tk.Tk()
root.title("YOLO v8 My App")

# Create a Canvas widget to display the webcam feed or video
canvas = tk.Canvas(root, width=1020, height=500)
canvas.pack(fill='both', expand=True)

class_list = read_classes_from_file('coco.txt')

class_selection = tk.StringVar()
class_selection.set("All")  # Default selection is "All"
class_selection_label = tk.Label(root, text="Select Class:")
class_selection_label.pack(side='left')
class_selection_entry = tk.OptionMenu(root, class_selection, "All", *class_list)  # Populate dropdown with classes from the text file
class_selection_entry.pack(side='left')

# Create a frame to hold the buttons
button_frame = tk.Frame(root)
button_frame.pack(fill='x')

# Create a "Play" button to start the webcam feed
play_button = tk.Button(button_frame, text="Play", command=start_webcam)
play_button.pack(side='left')

# Create a "Stop" button to stop the webcam feed
stop_button = tk.Button(button_frame, text="Stop", command=stop_webcam)
stop_button.pack(side='left')

# Create a "Select File" button to choose a video file
file_button = tk.Button(button_frame, text="Select File", command=select_file)
file_button.pack(side='left')

# Create a "Pause/Resume" button to pause or resume video
pause_button = tk.Button(button_frame, text="Pause/Resume", command=pause_resume_video)
pause_button.pack(side='left')

# Create a "Quit" button to close the application
quit_button = tk.Button(button_frame, text="Quit", command=quit_app)
quit_button.pack(side='left')

# Display an initial image on the canvas (replace 'initial_image.jpg' with your image)
initial_image = Image.open('yolo.jpg')  # Replace 'initial_image.jpg' with your image path
initial_photo = ImageTk.PhotoImage(image=initial_image)
canvas.img = initial_photo
canvas.create_image(0, 0, anchor=tk.NW, image=initial_photo)

# Start the Tkinter main loop
root.mainloop()
# Out:
# Downloading https:\github.com\ultralytics\assets\releases\download\v0.0.0\yolov8m.pt to 'yolov8m.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 49.7M/49.7M [00:45<00:00, 1.14MB/s]
#
# 0: 320x640 10 cars, 2 trucks, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 22.3ms
# Speed: 2.8ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 25.0ms
# Speed: 1.8ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 29.1ms
# Speed: 2.6ms preprocess, 29.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 29.4ms
# Speed: 2.2ms preprocess, 29.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 32.9ms
# Speed: 0.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 22.3ms
# Speed: 2.0ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.7ms
# Speed: 1.5ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.2ms
# Speed: 4.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 24.9ms
# Speed: 1.3ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 23.4ms
# Speed: 2.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.8ms
# Speed: 1.0ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.7ms
# Speed: 2.0ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 24.1ms
# Speed: 1.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 25.0ms
# Speed: 8.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 23.3ms
# Speed: 2.0ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.7ms
# Speed: 9.1ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.2ms
# Speed: 2.0ms preprocess, 26.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 28.1ms
# Speed: 2.0ms preprocess, 28.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 26.5ms
# Speed: 2.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 26.6ms
# Speed: 2.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 26.3ms
# Speed: 2.0ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.7ms
# Speed: 2.0ms preprocess, 27.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 21.9ms
# Speed: 2.0ms preprocess, 21.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.1ms
# Speed: 2.0ms preprocess, 28.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 23.9ms
# Speed: 9.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.9ms
# Speed: 1.5ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 26.7ms
# Speed: 2.0ms preprocess, 26.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 24.9ms
# Speed: 8.2ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 26.9ms
# Speed: 9.1ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.7ms
# Speed: 2.0ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 28.6ms
# Speed: 0.0ms preprocess, 28.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 truck, 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 24.9ms
# Speed: 8.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 26.4ms
# Speed: 2.0ms preprocess, 26.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 28.5ms
# Speed: 8.0ms preprocess, 28.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 26.3ms
# Speed: 1.0ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 24.9ms
# Speed: 8.1ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 32.9ms
# Speed: 0.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 25.3ms
# Speed: 2.0ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 26.2ms
# Speed: 1.0ms preprocess, 26.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 24.9ms
# Speed: 7.3ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 34.1ms
# Speed: 0.0ms preprocess, 34.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 26.9ms
# Speed: 8.2ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 27.5ms
# Speed: 1.6ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 truck, 27.0ms
# Speed: 1.8ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 5 cars, 28.1ms
# Speed: 7.7ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 truck, 29.8ms
# Speed: 0.0ms preprocess, 29.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 28.0ms
# Speed: 3.0ms preprocess, 28.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 truck, 28.1ms
# Speed: 2.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 truck, 27.0ms
# Speed: 4.6ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.7ms
# Speed: 2.0ms preprocess, 27.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 28.0ms
# Speed: 5.3ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 27.3ms
# Speed: 0.0ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 33.6ms
# Speed: 0.0ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 27.6ms
# Speed: 2.2ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 32.9ms
# Speed: 0.0ms preprocess, 32.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 24.9ms
# Speed: 5.2ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 30.2ms
# Speed: 0.0ms preprocess, 30.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.6ms
# Speed: 1.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 27.3ms
# Speed: 7.2ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 32.7ms
# Speed: 0.0ms preprocess, 32.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 31.2ms
# Speed: 0.0ms preprocess, 31.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 31.5ms
# Speed: 0.0ms preprocess, 31.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 26.8ms
# Speed: 3.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 truck, 28.0ms
# Speed: 2.4ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 29.7ms
# Speed: 0.0ms preprocess, 29.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.1ms
# Speed: 3.1ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 30.9ms
# Speed: 0.0ms preprocess, 30.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 30.1ms
# Speed: 0.0ms preprocess, 30.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.5ms
# Speed: 2.1ms preprocess, 27.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.5ms
# Speed: 3.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 28.5ms
# Speed: 0.8ms preprocess, 28.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 28.9ms
# Speed: 0.0ms preprocess, 28.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 26.9ms
# Speed: 2.9ms preprocess, 26.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 27.2ms
# Speed: 2.7ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 31.8ms
# Speed: 0.0ms preprocess, 31.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 28.1ms
# Speed: 1.1ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 2 trucks, 27.3ms
# Speed: 3.0ms preprocess, 27.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 27.8ms
# Speed: 1.0ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 2 trucks, 26.6ms
# Speed: 6.8ms preprocess, 26.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 28.2ms
# Speed: 2.0ms preprocess, 28.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 28.4ms
# Speed: 1.1ms preprocess, 28.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 31.1ms
# Speed: 0.0ms preprocess, 31.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 28.0ms
# Speed: 1.5ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 29.7ms
# Speed: 0.0ms preprocess, 29.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 29.4ms
# Speed: 0.0ms preprocess, 29.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.8ms
# Speed: 2.2ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 28.0ms
# Speed: 3.9ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.4ms
# Speed: 1.5ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.1ms
# Speed: 2.4ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 28.7ms
# Speed: 0.7ms preprocess, 28.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 28.5ms
# Speed: 0.9ms preprocess, 28.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 29.9ms
# Speed: 0.0ms preprocess, 29.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 28.9ms
# Speed: 0.5ms preprocess, 28.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.0ms
# Speed: 6.5ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 27.5ms
# Speed: 1.6ms preprocess, 27.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 27.2ms
# Speed: 1.3ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 29.0ms
# Speed: 1.5ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 27.1ms
# Speed: 2.4ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 26.9ms
# Speed: 1.6ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.3ms
# Speed: 1.9ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.7ms
# Speed: 1.8ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 27.6ms
# Speed: 2.2ms preprocess, 27.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.5ms
# Speed: 2.1ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.3ms
# Speed: 2.7ms preprocess, 27.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.7ms
# Speed: 1.7ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.4ms
# Speed: 2.0ms preprocess, 27.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 28.3ms
# Speed: 0.9ms preprocess, 28.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 27.7ms
# Speed: 1.6ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.8ms
# Speed: 1.7ms preprocess, 26.8ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 28.0ms
# Speed: 0.4ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 27.8ms
# Speed: 2.0ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 26.7ms
# Speed: 2.3ms preprocess, 26.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 truck, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.2ms
# Speed: 2.1ms preprocess, 27.2ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 27.8ms
# Speed: 1.6ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 27.4ms
# Speed: 1.0ms preprocess, 27.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 27.6ms
# Speed: 2.2ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 2 trucks, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.8ms
# Speed: 1.0ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 27.9ms
# Speed: 9.3ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 26.8ms
# Speed: 2.0ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 28.0ms
# Speed: 2.0ms preprocess, 28.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 26.3ms
# Speed: 2.3ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 27.8ms
# Speed: 1.0ms preprocess, 27.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 26.9ms
# Speed: 8.1ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.7ms
# Speed: 2.1ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 21.5ms
# Speed: 2.1ms preprocess, 21.5ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 26.9ms
# Speed: 2.0ms preprocess, 26.9ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 28.0ms
# Speed: 8.2ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 25.3ms
# Speed: 4.6ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 28.1ms
# Speed: 1.0ms preprocess, 28.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 22.2ms
# Speed: 2.4ms preprocess, 22.2ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.8ms
# Speed: 1.5ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 29.9ms
# Speed: 0.0ms preprocess, 29.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 28.0ms
# Speed: 1.0ms preprocess, 28.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 26.9ms
# Speed: 8.6ms preprocess, 26.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 27.7ms
# Speed: 1.5ms preprocess, 27.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 28.0ms
# Speed: 0.7ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 27.8ms
# Speed: 1.7ms preprocess, 27.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 26.1ms
# Speed: 7.5ms preprocess, 26.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.1ms
# Speed: 2.2ms preprocess, 27.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.2ms
# Speed: 2.0ms preprocess, 27.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 25.2ms
# Speed: 1.5ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 27.3ms
# Speed: 2.0ms preprocess, 27.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
